# %%
# %%writefile fhn1P.py
from modulus.models.fully_connected import FullyConnectedArch
from modulus.models.fourier_net import FourierNetArch
from modulus.models.siren import SirenArch
from modulus.models.modified_fourier_net import ModifiedFourierNetArch
from modulus.models.dgm import DGMArch

from sympy import Symbol, Eq
from sympy import Symbol, Function, Number
from modulus.eq.pde import PDE
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import modulus
from modulus.hydra import instantiate_arch, ModulusConfig
from modulus.solver import Solver
from modulus.domain import Domain
from modulus.geometry.primitives_1d import Point1D
from modulus.domain.constraint import (
    PointwiseBoundaryConstraint,
    PointwiseInteriorConstraint,
)
from modulus.domain.validator import PointwiseValidator
from modulus.key import Key
from modulus.node import Node
from modulus.eq.pde import PDE
from modulus.geometry import Parameterization
from sympy import Symbol, Eq, Abs, tanh, Or, And
from modulus.utils.io import (
    csv_to_dict,
    ValidatorPlotter,
    InferencerPlotter,
)
from modulus.solver import SequentialSolver

from modulus.models.deeponet import DeepONetArch
from modulus.domain.constraint.continuous import DeepONetConstraint
from modulus.models.moving_time_window import MovingTimeWindowArch
from modulus.domain.monitor import Monitor
from modulus.domain.constraint import Constraint
from modulus.graph import Graph
from modulus.key import Key
from modulus.constants import TF_SUMMARY
from modulus.distributed import DistributedManager
from modulus.utils.io import dict_to_csv, csv_to_dict
from modulus.domain.inferencer.pointwise import PointwiseInferencer as PointwiseInferencer

class MONI(Monitor):
    """
    Pointwise Inferencer that allows inferencing on pointwise data

    Parameters
    ----------
    invar : Dict[str, np.ndarray (N, 1)]
        Dictionary of numpy arrays as input.
    output_names : List[str]
        List of outputs needed for metric.
    metrics : Dict[str, Callable]
        Dictionary of pytorch functions whose input is a dictionary
        torch tensors whose keys are the `output_names`. The keys
        to `metrics` will be used to label the metrics in tensorboard/csv outputs.
    nodes : List[Node]
        List of Modulus Nodes to unroll graph with.
    requires_grad : bool = False
        If automatic differentiation is needed for computing results.
    """

    def __init__(self, invar, output_names, metrics, nodes, requires_grad=False):

        # construct model from nodes
        self.requires_grad = requires_grad
        self.model = Graph(
            nodes, Key.convert_list(invar.keys()), Key.convert_list(output_names)
        )
        self.manager = DistributedManager()
        self.device = self.manager.device
        self.model.to(self.device)

        # set metrics
        self.metrics = metrics
        self.monitor_outvar_store = {}

        # set invar
        self.invar = Constraint._set_device(invar, device=self.device)

    def save_results(self, name, writer, step, data_dir):
        plt.clf()
        # run forward inference
        invar = Constraint._set_device(
            self.invar, device=self.device, requires_grad=self.requires_grad
        )
        outvar = self.model(invar)
        metrics = {key: func({**invar, **outvar}) for key, func in self.metrics.items()}
        t=metrics["t"].detach().cpu().numpy()
        x1=metrics["x1"].detach().cpu().numpy()
        odex1=metrics["ode_x1"].detach().cpu().numpy()
        plt.scatter(t,x1)
        
        plt.savefig(data_dir+"x1s"+str(step)+".png")
        plt.clf()
        plt.scatter(t,odex1)
       # print(t)

        
        plt.savefig(data_dir+"ode_x1s"+str(step)+".png")
       
        return metrics

    
t_max = 10.0
n_w=1   
t_w= t_max/n_w
def generateExactSolution(t,dt,x0,rate,P,begin,end):
    
    
    n2=int(t/(dt))+2
    n = int((end-begin)/(dt*rate))
    Sol=np.zeros((n,3))
  
    Sol2=np.zeros((n2,2))
    Sol2[0]=x0,0
    T=0
    k=0
    while(k<n2-1):
        x,w=Sol2[k]
        Sol2[k+1]=10*(x*(x-0.4)*(1-x)-w)*dt+  x, 0.5*(x*0.2-0.8*w)*dt +w
 
        if ((k*dt==begin or ((k+1)%rate == 0 and k*dt>=begin and k*dt<=end))and T<n):
          
           
            Sol[T] = Sol2[k][0],Sol2[k][1] , k*dt
            T=T+1
        
        k=k+1
        if(k*dt > end):
            break
    return Sol

def generateValidator(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    krange= [(0 + 0.05*i*1) for i in range(0,20)]

    deltaT = 0.01
    
    rate=1
    for KR in krange:
        begin=w_i* t_w
        end=begin + t_w
        sol=generateExactSolution(t_max,deltaT,KR,rate,KR,begin,end)
        
        T=np.append(T,sol.T[2] - begin)
        K = np.append(K,np.full_like (sol.T[2],KR))
        SOLs=np.append(SOLs,sol.T[0])
        SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    validator = PointwiseValidator(
        nodes=nodes, invar=invar_numpy, true_outvar=outvar_numpy, batch_size=1024,plotter=ValidatorPlotter()
    )
    return validator

def generateDataC(w_i,nodes):

    
    
    T=np.empty([0])
    K=np.empty([0])
    SOLs=np.empty([0])
    SOLw=np.empty([0])
    krange= [(0.01 + 0.05*i*0.5) for i in range(0,40)]

    deltaT = 0.01
    
    rate=1
    for KR in krange:
        begin=w_i* t_w
        end=begin + t_w
        sol=generateExactSolution(t_max,deltaT,KR,rate,KR,begin,end)
        
        T=np.append(T,sol.T[2] - begin)
        K = np.append(K,np.full_like (sol.T[2],KR))
        SOLs=np.append(SOLs,sol.T[0])
        SOLw=np.append(SOLw,sol.T[1])
    
    
    t = np.expand_dims(T, axis=-1)


    k = np.expand_dims(K, axis=-1)

    
    Solx = np.expand_dims(SOLs, axis=-1)

    
    Solw = np.expand_dims(SOLw, axis=-1)
   
    
    print(t,"val set de ",begin,"a ", end)

    
    invar_numpy = {"t": t,"K":k}
    outvar_numpy = {
        "x1": Solx,
        "w":Solw
    }
   
    data = DeepONetConstraint.from_numpy(
        nodes=nodes,
        invar=invar_numpy,
        outvar=outvar_numpy,
        batch_size=1000,
        lambda_weighting=None
    )
    return data


class SpringMass(PDE):
    name = "SpringMass"

    def __init__(self):

        t = Symbol("t")
       
        input_variables = {"t": t}

        x = Function("x1")(*input_variables)
        w= Function("w")(*input_variables)
        self.equations = {}
        self.equations["ode_x1"] =10*(x*(x-0.4)*(1-x)-w) -x.diff(t)
        self.equations["ode_w"]  =0.5*(x*0.2-0.8*w) -w.diff(t)
        
@modulus.main(config_path="conf", config_name="config")
def run(cfg: ModulusConfig) -> None:
    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]


    
    # make list of nodes to unroll graph on
    sm = SpringMass()
    sm.pprint()
    #sm_net = FullyConnectedArch(
    #    input_keys=[Key("t"), Key("K")],
    #    output_keys=[Key("x1")],
    #)
    #nodes = sm.make_nodes() + [
    #    sm_net.make_node(name="network")
    #]

    
    
    flow_net = FullyConnectedArch(
            input_keys=[Key("t"), Key("K") ],
            output_keys=[Key("x1"),Key("w")],
            layer_size=16,
            nr_layers=4,
        )

    


    nodes = sm.make_nodes() +[ flow_net.make_node(name="network")]


    for node in nodes:
        print(node.__str__())
   
    # add constraints to solver
    # make geometry
    geo = Point1D(0)
    
    t_symbol = Symbol("t")
    x_symbol = Symbol("x1")
    k_symbol= Symbol("K")
    time_range = {t_symbol: (0,t_w )}
    k_range= {k_symbol:(0,1)}
    tr = {t_symbol: (0, t_w)}

    # make domain
        # make initial condition domain
    ic_domain = Domain("initial_conditions")

  
    # initial conditions
    IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1": k_symbol,"w":0},
        batch_size=1500,
        parameterization={**{t_symbol:0},**k_range},
        lambda_weighting={
            "x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        
        quasirandom=True,
    )

    ic_domain.add_constraint(IC, name="IC")
    
        # solve over given time period
    interior = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=1000,
        parameterization={**tr,**k_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior")
    interior2 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=1000,
        parameterization={**tr,**{k_symbol:(0.4,0.6)}},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 200,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 200 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,
    )
    ic_domain.add_constraint(interior, name="interior")

    
    
    
    domains=[]
    for i in range(1,n_w):

        # make moving window domain
        window_domain = Domain("window"+str(i))

        # solve over given time period
        interior1 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=2000,
        parameterization={**tr,**k_range},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 100,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 100 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        interior2 = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"ode_x1": 0.0,"ode_w":0.0},
        batch_size=2000,
        parameterization={**tr,**{k_symbol:(0.4,0.6)}},
        #criteria=And(t_symbol > 0, t_symbol < 3),
        lambda_weighting={
            "ode_x1": 200,# + 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol),
            "ode_w": 200 #+ 1000*x_symbol.diff(t_symbol)*x_symbol.diff(t_symbol)
        },
        quasirandom=True,

        )
        
        
        IC = PointwiseBoundaryConstraint(
        nodes=nodes,
        geometry=geo,
        outvar={"x1_prev_step_diff":0,"w_prev_step_diff":0},
        batch_size=1000,
        parameterization={**{t_symbol:0},**k_range},
        lambda_weighting={
            "x1_prev_step_diff": 1000,
            "w_prev_step_diff": 1000
        },
        
        quasirandom=True,
    )
        
    
        
        window_domain.add_constraint(IC, name="IC")
        window_domain.add_constraint(interior1, "interior")
        window_domain.add_constraint(interior2, "interiorTr")

        domains.append(window_domain)
    

    
 
    
    

    
    dom=[]
    dom.append((1,ic_domain))

    for domain in domains:
        dom.append((1,domain))
    print(cfg)
    # make solver
    #slv = Solver(cfg, domain)
    #print(domains)
    i=0
    for a,d in dom:
        print(d)
        print(d.name)
        d.add_validator(generateValidator(i,nodes))
        d.add_constraint(generateDataC(i,nodes))
        i=i+1
    
    slv = SequentialSolver(
        cfg,
        dom,
    )

    # start solver
    slv.solve()


        
        
        
if __name__ == "__main__":
    run()

# %%
# !rm -r outputs/fhn1P
# !python fhn1P.py
# Out:
# [02:41:44] - JitManager: {'_enabled': False, '_arch_mode': <JitArchMode.ONLY_ACTIVATION: 1>, '_use_nvfuser': True, '_autograd_nodes': False}
# [02:41:44] - GraphManager: {'_func_arch': False, '_debug': False, '_func_arch_allow_partial_hessian': True}
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# ode_x1: 10*(1 - x1)*(x1 - 0.4)*x1 - 10*w - x1__t
# ode_w: -0.4*w + 0.1*x1 - w__t
# node: Sympy Node: ode_x1
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [x1__t]
# outputs: [ode_x1]
# optimize: False
# node: Sympy Node: ode_w
# evaluate: SympyToTorch
# inputs: [w, x1]
# derivatives: [w__t]
# outputs: [ode_w]
# optimize: False
# node: Arch Node: network
# evaluate: FullyConnectedArch
# inputs: [t, K]
# derivatives: []
# outputs: [x1, w]
# optimize: True
# {'training': {'max_steps': 100000, 'grad_agg_freq': 1, 'rec_results_freq': 1000, 'rec_validation_freq': '${training.rec_results_freq}', 'rec_inference_freq': '${training.rec_results_freq}', 'rec_monitor_freq': '${training.rec_results_freq}', 'rec_constraint_freq': 2000, 'save_network_freq': 1000, 'print_stats_freq': 100, 'summary_freq': 1000, 'amp': False, 'amp_dtype': 'float16', 'ntk': {'use_ntk': False, 'save_name': None, 'run_freq': 1000}}, 'graph': {'func_arch': False, 'func_arch_allow_partial_hessian': True}, 'stop_criterion': {'metric': None, 'min_delta': None, 'patience': 50000, 'mode': 'min', 'freq': 1000, 'strict': False}, 'profiler': {'profile': False, 'start_step': 0, 'end_step': 100, 'name': 'nvtx'}, 'network_dir': '.', 'initialization_network_dir': '', 'save_filetypes': 'vtk', 'summary_histograms': False, 'jit': False, 'jit_use_nvfuser': True, 'jit_arch_mode': 'only_activation', 'jit_autograd_nodes': False, 'cuda_graphs': True, 'cuda_graph_warmup': 20, 'find_unused_parameters': False, 'broadcast_buffers': False, 'device': '', 'debug': False, 'run_mode': 'train', 'arch': {'fully_connected': {'arch_type': 'fully_connected', 'input_keys': '???', 'output_keys': '???', 'detach_keys': '???', 'scaling': None, 'layer_size': 512, 'nr_layers': 6, 'skip_connections': False, 'activation_fn': 'silu', 'adaptive_activations': False, 'weight_norm': True}}, 'models': '???', 'loss': {'_target_': 'modulus.loss.aggregator.Sum', 'weights': None}, 'optimizer': {'_params_': {'compute_gradients': 'adam_compute_gradients', 'apply_gradients': 'adam_apply_gradients'}, '_target_': 'torch.optim.Adam', 'lr': 0.001, 'betas': [0.9, 0.999], 'eps': 1e-08, 'weight_decay': 0.0, 'amsgrad': False}, 'scheduler': {'_target_': 'torch.optim.lr_scheduler.ExponentialLR', 'gamma': 0.99998718}, 'batch_size': {'initial_condition': 4096, 'interior': 4096}, 'custom': '???'}
# <modulus.domain.domain.Domain object at 0x7f5bbae5ab80>
# initial_conditions
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [9.97]
#  [9.98]
#  [9.99]] val set de  0.0 a  10.0
# [[0.  ]
#  [0.01]
#  [0.02]
#  ...
#  [9.97]
#  [9.98]
#  [9.99]] val set de  0.0 a  10.0
# [02:41:46] - Solving for Domain initial_conditions, iteration 0
# [02:41:46] - attempting to restore from: outputs/fhn1P/initial_conditions
# [02:41:46] - optimizer checkpoint not found
# [02:41:46] - model network.0.pth not found
# [02:41:47] - [step:          0] record constraint batch time:  5.588e-02s
# [02:41:50] - [step:          0] record validators time:  2.693e+00s
# [02:41:50] - [step:          0] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:41:50] - [step:          0] loss:  1.081e+05
# [02:41:50] - Attempting cuda graph building, this may take a bit...
# [02:41:52] - [step:        100] loss:  1.874e+02, time/iteration:  1.655e+01 ms
# [02:41:53] - [step:        200] loss:  1.510e+02, time/iteration:  1.289e+01 ms
# [02:41:54] - [step:        300] loss:  1.302e+02, time/iteration:  1.295e+01 ms
# [02:41:55] - [step:        400] loss:  9.775e+01, time/iteration:  1.298e+01 ms
# [02:41:57] - [step:        500] loss:  6.442e+01, time/iteration:  1.489e+01 ms
# [02:41:58] - [step:        600] loss:  5.286e+01, time/iteration:  1.298e+01 ms
# [02:42:00] - [step:        700] loss:  3.314e+01, time/iteration:  1.308e+01 ms
# [02:42:01] - [step:        800] loss:  2.643e+01, time/iteration:  1.295e+01 ms
# [02:42:02] - [step:        900] loss:  2.310e+01, time/iteration:  1.314e+01 ms
# [02:42:07] - [step:       1000] record validators time:  2.807e+00s
# [02:42:07] - [step:       1000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:42:07] - [step:       1000] loss:  2.160e+01, time/iteration:  4.475e+01 ms
# [02:42:08] - [step:       1100] loss:  2.202e+01, time/iteration:  1.303e+01 ms
# [02:42:09] - [step:       1200] loss:  1.917e+01, time/iteration:  1.297e+01 ms
# [02:42:11] - [step:       1300] loss:  1.909e+01, time/iteration:  1.332e+01 ms
# [02:42:12] - [step:       1400] loss:  2.077e+01, time/iteration:  1.295e+01 ms
# [02:42:13] - [step:       1500] loss:  1.917e+01, time/iteration:  1.437e+01 ms
# [02:42:15] - [step:       1600] loss:  1.617e+01, time/iteration:  1.321e+01 ms
# [02:42:16] - [step:       1700] loss:  1.667e+01, time/iteration:  1.283e+01 ms
# [02:42:17] - [step:       1800] loss:  1.610e+01, time/iteration:  1.316e+01 ms
# [02:42:19] - [step:       1900] loss:  1.790e+01, time/iteration:  1.283e+01 ms
# [02:42:20] - [step:       2000] record constraint batch time:  3.241e-02s
# [02:42:23] - [step:       2000] record validators time:  2.652e+00s
# [02:42:23] - [step:       2000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:42:23] - [step:       2000] loss:  1.695e+01, time/iteration:  4.333e+01 ms
# [02:42:24] - [step:       2100] loss:  1.629e+01, time/iteration:  1.294e+01 ms
# [02:42:25] - [step:       2200] loss:  1.723e+01, time/iteration:  1.313e+01 ms
# [02:42:27] - [step:       2300] loss:  1.714e+01, time/iteration:  1.315e+01 ms
# [02:42:28] - [step:       2400] loss:  1.575e+01, time/iteration:  1.279e+01 ms
# [02:42:30] - [step:       2500] loss:  1.562e+01, time/iteration:  1.451e+01 ms
# [02:42:31] - [step:       2600] loss:  1.553e+01, time/iteration:  1.299e+01 ms
# [02:42:32] - [step:       2700] loss:  1.559e+01, time/iteration:  1.271e+01 ms
# [02:42:33] - [step:       2800] loss:  1.314e+01, time/iteration:  1.280e+01 ms
# [02:42:35] - [step:       2900] loss:  1.675e+01, time/iteration:  1.307e+01 ms
# [02:42:39] - [step:       3000] record validators time:  2.621e+00s
# [02:42:39] - [step:       3000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:42:39] - [step:       3000] loss:  1.611e+01, time/iteration:  4.250e+01 ms
# [02:42:40] - [step:       3100] loss:  1.501e+01, time/iteration:  1.288e+01 ms
# [02:42:42] - [step:       3200] loss:  1.503e+01, time/iteration:  1.295e+01 ms
# [02:42:43] - [step:       3300] loss:  1.413e+01, time/iteration:  1.278e+01 ms
# [02:42:44] - [step:       3400] loss:  1.397e+01, time/iteration:  1.300e+01 ms
# [02:42:46] - [step:       3500] loss:  1.321e+01, time/iteration:  1.463e+01 ms
# [02:42:47] - [step:       3600] loss:  1.274e+01, time/iteration:  1.349e+01 ms
# [02:42:48] - [step:       3700] loss:  1.115e+01, time/iteration:  1.301e+01 ms
# [02:42:50] - [step:       3800] loss:  1.165e+01, time/iteration:  1.310e+01 ms
# [02:42:51] - [step:       3900] loss:  1.128e+01, time/iteration:  1.318e+01 ms
# [02:42:53] - [step:       4000] record constraint batch time:  3.267e-02s
# [02:42:55] - [step:       4000] record validators time:  2.910e+00s
# [02:42:55] - [step:       4000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:42:55] - [step:       4000] loss:  1.272e+01, time/iteration:  4.601e+01 ms
# [02:42:57] - [step:       4100] loss:  1.059e+01, time/iteration:  1.335e+01 ms
# [02:42:58] - [step:       4200] loss:  1.046e+01, time/iteration:  1.297e+01 ms
# [02:42:59] - [step:       4300] loss:  1.222e+01, time/iteration:  1.289e+01 ms
# [02:43:01] - [step:       4400] loss:  1.016e+01, time/iteration:  1.303e+01 ms
# [02:43:02] - [step:       4500] loss:  9.248e+00, time/iteration:  1.471e+01 ms
# [02:43:03] - [step:       4600] loss:  1.056e+01, time/iteration:  1.323e+01 ms
# [02:43:05] - [step:       4700] loss:  8.982e+00, time/iteration:  1.314e+01 ms
# [02:43:06] - [step:       4800] loss:  9.921e+00, time/iteration:  1.288e+01 ms
# [02:43:07] - [step:       4900] loss:  8.898e+00, time/iteration:  1.332e+01 ms
# [02:43:12] - [step:       5000] record validators time:  2.736e+00s
# [02:43:12] - [step:       5000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:43:12] - [step:       5000] loss:  9.408e+00, time/iteration:  4.369e+01 ms
# [02:43:13] - [step:       5100] loss:  9.652e+00, time/iteration:  1.294e+01 ms
# [02:43:14] - [step:       5200] loss:  9.677e+00, time/iteration:  1.285e+01 ms
# [02:43:16] - [step:       5300] loss:  9.293e+00, time/iteration:  1.295e+01 ms
# [02:43:17] - [step:       5400] loss:  8.486e+00, time/iteration:  1.314e+01 ms
# [02:43:18] - [step:       5500] loss:  8.448e+00, time/iteration:  1.411e+01 ms
# [02:43:20] - [step:       5600] loss:  8.762e+00, time/iteration:  1.319e+01 ms
# [02:43:21] - [step:       5700] loss:  9.460e+00, time/iteration:  1.288e+01 ms
# [02:43:22] - [step:       5800] loss:  7.665e+00, time/iteration:  1.293e+01 ms
# [02:43:24] - [step:       5900] loss:  8.285e+00, time/iteration:  1.294e+01 ms
# [02:43:25] - [step:       6000] record constraint batch time:  3.299e-02s
# [02:43:28] - [step:       6000] record validators time:  2.768e+00s
# [02:43:28] - [step:       6000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:43:28] - [step:       6000] loss:  8.120e+00, time/iteration:  4.455e+01 ms
# [02:43:29] - [step:       6100] loss:  7.476e+00, time/iteration:  1.300e+01 ms
# [02:43:31] - [step:       6200] loss:  8.599e+00, time/iteration:  1.325e+01 ms
# [02:43:32] - [step:       6300] loss:  6.669e+00, time/iteration:  1.305e+01 ms
# [02:43:33] - [step:       6400] loss:  7.654e+00, time/iteration:  1.293e+01 ms
# [02:43:35] - [step:       6500] loss:  6.986e+00, time/iteration:  1.458e+01 ms
# [02:43:36] - [step:       6600] loss:  8.177e+00, time/iteration:  1.298e+01 ms
# [02:43:37] - [step:       6700] loss:  7.064e+00, time/iteration:  1.315e+01 ms
# [02:43:39] - [step:       6800] loss:  6.429e+00, time/iteration:  1.295e+01 ms
# [02:43:40] - [step:       6900] loss:  7.237e+00, time/iteration:  1.307e+01 ms
# [02:43:44] - [step:       7000] record validators time:  2.795e+00s
# [02:43:44] - [step:       7000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:43:44] - [step:       7000] loss:  7.268e+00, time/iteration:  4.466e+01 ms
# [02:43:46] - [step:       7100] loss:  6.042e+00, time/iteration:  1.353e+01 ms
# [02:43:47] - [step:       7200] loss:  5.575e+00, time/iteration:  1.339e+01 ms
# [02:43:48] - [step:       7300] loss:  5.645e+00, time/iteration:  1.284e+01 ms
# [02:43:50] - [step:       7400] loss:  5.787e+00, time/iteration:  1.290e+01 ms
# [02:43:51] - [step:       7500] loss:  4.886e+00, time/iteration:  1.397e+01 ms
# [02:43:52] - [step:       7600] loss:  5.066e+00, time/iteration:  1.278e+01 ms
# [02:43:54] - [step:       7700] loss:  5.513e+00, time/iteration:  1.261e+01 ms
# [02:43:55] - [step:       7800] loss:  5.799e+00, time/iteration:  1.283e+01 ms
# [02:43:56] - [step:       7900] loss:  5.506e+00, time/iteration:  1.271e+01 ms
# [02:43:58] - [step:       8000] record constraint batch time:  3.195e-02s
# [02:44:01] - [step:       8000] record validators time:  2.704e+00s
# [02:44:01] - [step:       8000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:44:01] - [step:       8000] loss:  5.549e+00, time/iteration:  4.394e+01 ms
# [02:44:02] - [step:       8100] loss:  5.707e+00, time/iteration:  1.294e+01 ms
# [02:44:03] - [step:       8200] loss:  5.724e+00, time/iteration:  1.286e+01 ms
# [02:44:04] - [step:       8300] loss:  5.526e+00, time/iteration:  1.283e+01 ms
# [02:44:06] - [step:       8400] loss:  4.098e+00, time/iteration:  1.310e+01 ms
# [02:44:07] - [step:       8500] loss:  5.067e+00, time/iteration:  1.430e+01 ms
# [02:44:08] - [step:       8600] loss:  3.905e+00, time/iteration:  1.296e+01 ms
# [02:44:10] - [step:       8700] loss:  4.872e+00, time/iteration:  1.305e+01 ms
# [02:44:11] - [step:       8800] loss:  4.462e+00, time/iteration:  1.306e+01 ms
# [02:44:12] - [step:       8900] loss:  3.914e+00, time/iteration:  1.306e+01 ms
# [02:44:17] - [step:       9000] record validators time:  2.706e+00s
# [02:44:17] - [step:       9000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:44:17] - [step:       9000] loss:  4.101e+00, time/iteration:  4.333e+01 ms
# [02:44:18] - [step:       9100] loss:  4.760e+00, time/iteration:  1.300e+01 ms
# [02:44:19] - [step:       9200] loss:  3.800e+00, time/iteration:  1.287e+01 ms
# [02:44:21] - [step:       9300] loss:  4.266e+00, time/iteration:  1.312e+01 ms
# [02:44:22] - [step:       9400] loss:  3.863e+00, time/iteration:  1.286e+01 ms
# [02:44:23] - [step:       9500] loss:  3.756e+00, time/iteration:  1.432e+01 ms
# [02:44:25] - [step:       9600] loss:  4.216e+00, time/iteration:  1.312e+01 ms
# [02:44:26] - [step:       9700] loss:  4.081e+00, time/iteration:  1.313e+01 ms
# [02:44:27] - [step:       9800] loss:  3.900e+00, time/iteration:  1.327e+01 ms
# [02:44:29] - [step:       9900] loss:  3.707e+00, time/iteration:  1.277e+01 ms
# [02:44:30] - [step:      10000] record constraint batch time:  3.176e-02s
# [02:44:33] - [step:      10000] record validators time:  2.556e+00s
# [02:44:33] - [step:      10000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:44:33] - [step:      10000] loss:  3.344e+00, time/iteration:  4.242e+01 ms
# [02:44:34] - [step:      10100] loss:  4.312e+00, time/iteration:  1.269e+01 ms
# [02:44:35] - [step:      10200] loss:  3.656e+00, time/iteration:  1.360e+01 ms
# [02:44:37] - [step:      10300] loss:  3.483e+00, time/iteration:  1.352e+01 ms
# [02:44:38] - [step:      10400] loss:  3.169e+00, time/iteration:  1.359e+01 ms
# [02:44:40] - [step:      10500] loss:  3.538e+00, time/iteration:  1.483e+01 ms
# [02:44:41] - [step:      10600] loss:  4.052e+00, time/iteration:  1.350e+01 ms
# [02:44:42] - [step:      10700] loss:  3.299e+00, time/iteration:  1.377e+01 ms
# [02:44:44] - [step:      10800] loss:  2.894e+00, time/iteration:  1.337e+01 ms
# [02:44:45] - [step:      10900] loss:  2.767e+00, time/iteration:  1.334e+01 ms
# [02:44:50] - [step:      11000] record validators time:  2.972e+00s
# [02:44:50] - [step:      11000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:44:50] - [step:      11000] loss:  2.977e+00, time/iteration:  4.724e+01 ms
# [02:44:51] - [step:      11100] loss:  3.200e+00, time/iteration:  1.360e+01 ms
# [02:44:52] - [step:      11200] loss:  3.064e+00, time/iteration:  1.334e+01 ms
# [02:44:54] - [step:      11300] loss:  2.572e+00, time/iteration:  1.355e+01 ms
# [02:44:55] - [step:      11400] loss:  3.213e+00, time/iteration:  1.376e+01 ms
# [02:44:57] - [step:      11500] loss:  2.289e+00, time/iteration:  1.493e+01 ms
# [02:44:58] - [step:      11600] loss:  2.550e+00, time/iteration:  1.330e+01 ms
# [02:44:59] - [step:      11700] loss:  2.664e+00, time/iteration:  1.317e+01 ms
# [02:45:01] - [step:      11800] loss:  2.706e+00, time/iteration:  1.362e+01 ms
# [02:45:02] - [step:      11900] loss:  2.497e+00, time/iteration:  1.331e+01 ms
# [02:45:04] - [step:      12000] record constraint batch time:  3.387e-02s
# [02:45:07] - [step:      12000] record validators time:  2.809e+00s
# [02:45:07] - [step:      12000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:45:07] - [step:      12000] loss:  2.463e+00, time/iteration:  4.544e+01 ms
# [02:45:08] - [step:      12100] loss:  2.084e+00, time/iteration:  1.383e+01 ms
# [02:45:09] - [step:      12200] loss:  1.906e+00, time/iteration:  1.333e+01 ms
# [02:45:11] - [step:      12300] loss:  2.345e+00, time/iteration:  1.344e+01 ms
# [02:45:12] - [step:      12400] loss:  1.991e+00, time/iteration:  1.417e+01 ms
# [02:45:13] - [step:      12500] loss:  1.421e+00, time/iteration:  1.486e+01 ms
# [02:45:15] - [step:      12600] loss:  2.327e+00, time/iteration:  1.360e+01 ms
# [02:45:16] - [step:      12700] loss:  2.044e+00, time/iteration:  1.332e+01 ms
# [02:45:18] - [step:      12800] loss:  2.098e+00, time/iteration:  1.357e+01 ms
# [02:45:19] - [step:      12900] loss:  1.528e+00, time/iteration:  1.298e+01 ms
# [02:45:23] - [step:      13000] record validators time:  2.719e+00s
# [02:45:23] - [step:      13000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:45:23] - [step:      13000] loss:  1.620e+00, time/iteration:  4.468e+01 ms
# [02:45:25] - [step:      13100] loss:  1.795e+00, time/iteration:  1.348e+01 ms
# [02:45:26] - [step:      13200] loss:  1.891e+00, time/iteration:  1.380e+01 ms
# [02:45:27] - [step:      13300] loss:  1.873e+00, time/iteration:  1.383e+01 ms
# [02:45:29] - [step:      13400] loss:  2.027e+00, time/iteration:  1.298e+01 ms
# [02:45:30] - [step:      13500] loss:  1.729e+00, time/iteration:  1.452e+01 ms
# [02:45:31] - [step:      13600] loss:  1.544e+00, time/iteration:  1.322e+01 ms
# [02:45:33] - [step:      13700] loss:  1.820e+00, time/iteration:  1.309e+01 ms
# [02:45:34] - [step:      13800] loss:  1.305e+00, time/iteration:  1.339e+01 ms
# [02:45:35] - [step:      13900] loss:  1.731e+00, time/iteration:  1.363e+01 ms
# [02:45:37] - [step:      14000] record constraint batch time:  3.384e-02s
# [02:45:40] - [step:      14000] record validators time:  2.919e+00s
# [02:45:40] - [step:      14000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:45:40] - [step:      14000] loss:  1.224e+00, time/iteration:  4.694e+01 ms
# [02:45:42] - [step:      14100] loss:  1.521e+00, time/iteration:  1.380e+01 ms
# [02:45:43] - [step:      14200] loss:  1.472e+00, time/iteration:  1.390e+01 ms
# [02:45:44] - [step:      14300] loss:  1.514e+00, time/iteration:  1.326e+01 ms
# [02:45:46] - [step:      14400] loss:  1.364e+00, time/iteration:  1.377e+01 ms
# [02:45:47] - [step:      14500] loss:  1.182e+00, time/iteration:  1.492e+01 ms
# [02:45:48] - [step:      14600] loss:  1.108e+00, time/iteration:  1.331e+01 ms
# [02:45:50] - [step:      14700] loss:  9.892e-01, time/iteration:  1.339e+01 ms
# [02:45:51] - [step:      14800] loss:  1.180e+00, time/iteration:  1.353e+01 ms
# [02:45:53] - [step:      14900] loss:  1.036e+00, time/iteration:  1.373e+01 ms
# [02:45:57] - [step:      15000] record validators time:  2.820e+00s
# [02:45:57] - [step:      15000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:45:57] - [step:      15000] loss:  1.020e+00, time/iteration:  4.518e+01 ms
# [02:45:58] - [step:      15100] loss:  1.177e+00, time/iteration:  1.360e+01 ms
# [02:46:00] - [step:      15200] loss:  9.760e-01, time/iteration:  1.344e+01 ms
# [02:46:01] - [step:      15300] loss:  1.038e+00, time/iteration:  1.361e+01 ms
# [02:46:02] - [step:      15400] loss:  1.194e+00, time/iteration:  1.347e+01 ms
# [02:46:04] - [step:      15500] loss:  1.256e+00, time/iteration:  1.455e+01 ms
# [02:46:05] - [step:      15600] loss:  1.134e+00, time/iteration:  1.385e+01 ms
# [02:46:07] - [step:      15700] loss:  9.088e-01, time/iteration:  1.381e+01 ms
# [02:46:08] - [step:      15800] loss:  1.117e+00, time/iteration:  1.373e+01 ms
# [02:46:09] - [step:      15900] loss:  1.023e+00, time/iteration:  1.359e+01 ms
# [02:46:11] - [step:      16000] record constraint batch time:  3.503e-02s
# [02:46:14] - [step:      16000] record validators time:  2.794e+00s
# [02:46:14] - [step:      16000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:46:14] - [step:      16000] loss:  1.085e+00, time/iteration:  4.577e+01 ms
# [02:46:15] - [step:      16100] loss:  9.675e-01, time/iteration:  1.394e+01 ms
# [02:46:17] - [step:      16200] loss:  9.899e-01, time/iteration:  1.378e+01 ms
# [02:46:18] - [step:      16300] loss:  8.078e-01, time/iteration:  1.332e+01 ms
# [02:46:19] - [step:      16400] loss:  7.541e-01, time/iteration:  1.323e+01 ms
# [02:46:21] - [step:      16500] loss:  8.274e-01, time/iteration:  1.458e+01 ms
# [02:46:22] - [step:      16600] loss:  7.954e-01, time/iteration:  1.340e+01 ms
# [02:46:24] - [step:      16700] loss:  9.187e-01, time/iteration:  1.358e+01 ms
# [02:46:25] - [step:      16800] loss:  8.345e-01, time/iteration:  1.391e+01 ms
# [02:46:26] - [step:      16900] loss:  1.000e+00, time/iteration:  1.437e+01 ms
# [02:46:31] - [step:      17000] record validators time:  2.736e+00s
# [02:46:31] - [step:      17000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:46:31] - [step:      17000] loss:  1.020e+00, time/iteration:  4.460e+01 ms
# [02:46:32] - [step:      17100] loss:  8.406e-01, time/iteration:  1.397e+01 ms
# [02:46:34] - [step:      17200] loss:  7.129e-01, time/iteration:  1.345e+01 ms
# [02:46:35] - [step:      17300] loss:  7.189e-01, time/iteration:  1.349e+01 ms
# [02:46:36] - [step:      17400] loss:  8.263e-01, time/iteration:  1.371e+01 ms
# [02:46:38] - [step:      17500] loss:  7.844e-01, time/iteration:  1.460e+01 ms
# [02:46:39] - [step:      17600] loss:  7.074e-01, time/iteration:  1.352e+01 ms
# [02:46:41] - [step:      17700] loss:  8.141e-01, time/iteration:  1.373e+01 ms
# [02:46:42] - [step:      17800] loss:  6.812e-01, time/iteration:  1.397e+01 ms
# [02:46:43] - [step:      17900] loss:  8.211e-01, time/iteration:  1.498e+01 ms
# [02:46:45] - [step:      18000] record constraint batch time:  4.962e-02s
# [02:46:48] - [step:      18000] record validators time:  3.019e+00s
# [02:46:48] - [step:      18000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:46:48] - [step:      18000] loss:  8.053e-01, time/iteration:  4.853e+01 ms
# [02:46:50] - [step:      18100] loss:  8.427e-01, time/iteration:  1.437e+01 ms
# [02:46:51] - [step:      18200] loss:  6.904e-01, time/iteration:  1.379e+01 ms
# [02:46:52] - [step:      18300] loss:  7.671e-01, time/iteration:  1.349e+01 ms
# [02:46:54] - [step:      18400] loss:  7.279e-01, time/iteration:  1.346e+01 ms
# [02:46:55] - [step:      18500] loss:  7.009e-01, time/iteration:  1.505e+01 ms
# [02:46:57] - [step:      18600] loss:  6.084e-01, time/iteration:  1.403e+01 ms
# [02:46:58] - [step:      18700] loss:  8.056e-01, time/iteration:  1.390e+01 ms
# [02:46:59] - [step:      18800] loss:  9.017e-01, time/iteration:  1.359e+01 ms
# [02:47:01] - [step:      18900] loss:  5.649e-01, time/iteration:  1.376e+01 ms
# [02:47:05] - [step:      19000] record validators time:  2.840e+00s
# [02:47:05] - [step:      19000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:47:05] - [step:      19000] loss:  6.245e-01, time/iteration:  4.615e+01 ms
# [02:47:07] - [step:      19100] loss:  5.117e-01, time/iteration:  1.463e+01 ms
# [02:47:08] - [step:      19200] loss:  5.149e-01, time/iteration:  1.380e+01 ms
# [02:47:10] - [step:      19300] loss:  5.215e-01, time/iteration:  1.334e+01 ms
# [02:47:11] - [step:      19400] loss:  6.531e-01, time/iteration:  1.358e+01 ms
# [02:47:12] - [step:      19500] loss:  5.700e-01, time/iteration:  1.467e+01 ms
# [02:47:14] - [step:      19600] loss:  3.850e-01, time/iteration:  1.440e+01 ms
# [02:47:15] - [step:      19700] loss:  5.654e-01, time/iteration:  1.368e+01 ms
# [02:47:17] - [step:      19800] loss:  5.344e-01, time/iteration:  1.457e+01 ms
# [02:47:18] - [step:      19900] loss:  5.439e-01, time/iteration:  1.409e+01 ms
# [02:47:20] - [step:      20000] record constraint batch time:  3.289e-02s
# [02:47:23] - [step:      20000] record validators time:  2.780e+00s
# [02:47:23] - [step:      20000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:47:23] - [step:      20000] loss:  6.113e-01, time/iteration:  4.681e+01 ms
# [02:47:24] - [step:      20100] loss:  5.669e-01, time/iteration:  1.357e+01 ms
# [02:47:26] - [step:      20200] loss:  5.724e-01, time/iteration:  1.388e+01 ms
# [02:47:27] - [step:      20300] loss:  5.501e-01, time/iteration:  1.401e+01 ms
# [02:47:28] - [step:      20400] loss:  4.985e-01, time/iteration:  1.344e+01 ms
# [02:47:30] - [step:      20500] loss:  4.489e-01, time/iteration:  1.491e+01 ms
# [02:47:31] - [step:      20600] loss:  3.815e-01, time/iteration:  1.403e+01 ms
# [02:47:33] - [step:      20700] loss:  4.652e-01, time/iteration:  1.495e+01 ms
# [02:47:34] - [step:      20800] loss:  4.764e-01, time/iteration:  1.496e+01 ms
# [02:47:36] - [step:      20900] loss:  4.359e-01, time/iteration:  1.687e+01 ms
# [02:47:42] - [step:      21000] record validators time:  2.923e+00s
# [02:47:42] - [step:      21000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:47:42] - [step:      21000] loss:  3.941e-01, time/iteration:  5.806e+01 ms
# [02:47:43] - [step:      21100] loss:  4.144e-01, time/iteration:  1.359e+01 ms
# [02:47:44] - [step:      21200] loss:  4.912e-01, time/iteration:  1.418e+01 ms
# [02:47:46] - [step:      21300] loss:  3.609e-01, time/iteration:  1.391e+01 ms
# [02:47:47] - [step:      21400] loss:  6.114e-01, time/iteration:  1.414e+01 ms
# [02:47:49] - [step:      21500] loss:  3.737e-01, time/iteration:  1.469e+01 ms
# [02:47:50] - [step:      21600] loss:  5.382e-01, time/iteration:  1.374e+01 ms
# [02:47:51] - [step:      21700] loss:  4.025e-01, time/iteration:  1.322e+01 ms
# [02:47:53] - [step:      21800] loss:  3.511e-01, time/iteration:  1.332e+01 ms
# [02:47:54] - [step:      21900] loss:  4.951e-01, time/iteration:  1.302e+01 ms
# [02:47:56] - [step:      22000] record constraint batch time:  3.308e-02s
# [02:47:58] - [step:      22000] record validators time:  2.689e+00s
# [02:47:58] - [step:      22000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:47:58] - [step:      22000] loss:  4.256e-01, time/iteration:  4.388e+01 ms
# [02:48:00] - [step:      22100] loss:  4.066e-01, time/iteration:  1.322e+01 ms
# [02:48:01] - [step:      22200] loss:  3.087e-01, time/iteration:  1.332e+01 ms
# [02:48:02] - [step:      22300] loss:  3.755e-01, time/iteration:  1.331e+01 ms
# [02:48:04] - [step:      22400] loss:  3.469e-01, time/iteration:  1.319e+01 ms
# [02:48:05] - [step:      22500] loss:  3.622e-01, time/iteration:  1.492e+01 ms
# [02:48:07] - [step:      22600] loss:  3.130e-01, time/iteration:  1.354e+01 ms
# [02:48:08] - [step:      22700] loss:  3.771e-01, time/iteration:  1.326e+01 ms
# [02:48:09] - [step:      22800] loss:  3.223e-01, time/iteration:  1.294e+01 ms
# [02:48:11] - [step:      22900] loss:  3.001e-01, time/iteration:  1.339e+01 ms
# [02:48:15] - [step:      23000] record validators time:  2.889e+00s
# [02:48:15] - [step:      23000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:48:15] - [step:      23000] loss:  2.369e-01, time/iteration:  4.598e+01 ms
# [02:48:17] - [step:      23100] loss:  4.078e-01, time/iteration:  1.370e+01 ms
# [02:48:18] - [step:      23200] loss:  3.114e-01, time/iteration:  1.305e+01 ms
# [02:48:19] - [step:      23300] loss:  2.423e-01, time/iteration:  1.290e+01 ms
# [02:48:20] - [step:      23400] loss:  2.819e-01, time/iteration:  1.325e+01 ms
# [02:48:22] - [step:      23500] loss:  3.509e-01, time/iteration:  1.439e+01 ms
# [02:48:23] - [step:      23600] loss:  3.858e-01, time/iteration:  1.329e+01 ms
# [02:48:25] - [step:      23700] loss:  3.195e-01, time/iteration:  1.283e+01 ms
# [02:48:26] - [step:      23800] loss:  3.066e-01, time/iteration:  1.355e+01 ms
# [02:48:27] - [step:      23900] loss:  2.114e-01, time/iteration:  1.389e+01 ms
# [02:48:29] - [step:      24000] record constraint batch time:  4.971e-02s
# [02:48:32] - [step:      24000] record validators time:  2.709e+00s
# [02:48:32] - [step:      24000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:48:32] - [step:      24000] loss:  2.563e-01, time/iteration:  4.602e+01 ms
# [02:48:33] - [step:      24100] loss:  3.606e-01, time/iteration:  1.525e+01 ms
# [02:48:35] - [step:      24200] loss:  3.630e-01, time/iteration:  1.584e+01 ms
# [02:48:36] - [step:      24300] loss:  2.314e-01, time/iteration:  1.525e+01 ms
# [02:48:38] - [step:      24400] loss:  2.855e-01, time/iteration:  1.482e+01 ms
# [02:48:40] - [step:      24500] loss:  2.214e-01, time/iteration:  1.911e+01 ms
# [02:48:41] - [step:      24600] loss:  3.091e-01, time/iteration:  1.550e+01 ms
# [02:48:43] - [step:      24700] loss:  2.597e-01, time/iteration:  1.544e+01 ms
# [02:48:45] - [step:      24800] loss:  3.131e-01, time/iteration:  1.862e+01 ms
# [02:48:47] - [step:      24900] loss:  3.406e-01, time/iteration:  1.686e+01 ms
# [02:48:52] - [step:      25000] record validators time:  3.106e+00s
# [02:48:52] - [step:      25000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:48:52] - [step:      25000] loss:  2.611e-01, time/iteration:  5.180e+01 ms
# [02:48:53] - [step:      25100] loss:  2.551e-01, time/iteration:  1.651e+01 ms
# [02:48:55] - [step:      25200] loss:  2.401e-01, time/iteration:  1.621e+01 ms
# [02:48:57] - [step:      25300] loss:  2.532e-01, time/iteration:  1.825e+01 ms
# [02:48:59] - [step:      25400] loss:  4.717e-01, time/iteration:  1.854e+01 ms
# [02:49:00] - [step:      25500] loss:  1.481e-01, time/iteration:  1.761e+01 ms
# [02:49:03] - [step:      25600] loss:  2.855e-01, time/iteration:  2.135e+01 ms
# [02:49:04] - [step:      25700] loss:  1.959e-01, time/iteration:  1.817e+01 ms
# [02:49:06] - [step:      25800] loss:  2.945e-01, time/iteration:  1.859e+01 ms
# [02:49:08] - [step:      25900] loss:  2.563e-01, time/iteration:  1.943e+01 ms
# [02:49:10] - [step:      26000] record constraint batch time:  3.374e-02s
# [02:49:13] - [step:      26000] record validators time:  2.782e+00s
# [02:49:13] - [step:      26000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:49:13] - [step:      26000] loss:  2.665e-01, time/iteration:  4.965e+01 ms
# [02:49:15] - [step:      26100] loss:  2.199e-01, time/iteration:  2.066e+01 ms
# [02:49:17] - [step:      26200] loss:  2.444e-01, time/iteration:  1.896e+01 ms
# [02:49:18] - [step:      26300] loss:  1.775e-01, time/iteration:  1.370e+01 ms
# [02:49:20] - [step:      26400] loss:  1.710e-01, time/iteration:  1.837e+01 ms
# [02:49:22] - [step:      26500] loss:  2.331e-01, time/iteration:  1.693e+01 ms
# [02:49:23] - [step:      26600] loss:  2.342e-01, time/iteration:  1.319e+01 ms
# [02:49:25] - [step:      26700] loss:  2.275e-01, time/iteration:  1.313e+01 ms
# [02:49:26] - [step:      26800] loss:  1.850e-01, time/iteration:  1.314e+01 ms
# [02:49:27] - [step:      26900] loss:  2.189e-01, time/iteration:  1.357e+01 ms
# [02:49:32] - [step:      27000] record validators time:  2.669e+00s
# [02:49:32] - [step:      27000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:49:32] - [step:      27000] loss:  1.831e-01, time/iteration:  4.303e+01 ms
# [02:49:33] - [step:      27100] loss:  1.518e-01, time/iteration:  1.316e+01 ms
# [02:49:34] - [step:      27200] loss:  1.749e-01, time/iteration:  1.297e+01 ms
# [02:49:36] - [step:      27300] loss:  2.344e-01, time/iteration:  1.309e+01 ms
# [02:49:37] - [step:      27400] loss:  1.570e-01, time/iteration:  1.323e+01 ms
# [02:49:38] - [step:      27500] loss:  1.884e-01, time/iteration:  1.416e+01 ms
# [02:49:40] - [step:      27600] loss:  1.910e-01, time/iteration:  1.300e+01 ms
# [02:49:41] - [step:      27700] loss:  2.047e-01, time/iteration:  1.296e+01 ms
# [02:49:42] - [step:      27800] loss:  2.076e-01, time/iteration:  1.309e+01 ms
# [02:49:43] - [step:      27900] loss:  2.166e-01, time/iteration:  1.292e+01 ms
# [02:49:45] - [step:      28000] record constraint batch time:  3.213e-02s
# [02:49:48] - [step:      28000] record validators time:  2.819e+00s
# [02:49:48] - [step:      28000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:49:48] - [step:      28000] loss:  1.814e-01, time/iteration:  4.500e+01 ms
# [02:49:49] - [step:      28100] loss:  1.803e-01, time/iteration:  1.306e+01 ms
# [02:49:51] - [step:      28200] loss:  2.564e-01, time/iteration:  1.320e+01 ms
# [02:49:52] - [step:      28300] loss:  1.784e-01, time/iteration:  1.282e+01 ms
# [02:49:53] - [step:      28400] loss:  1.901e-01, time/iteration:  1.299e+01 ms
# [02:49:55] - [step:      28500] loss:  1.909e-01, time/iteration:  1.396e+01 ms
# [02:49:56] - [step:      28600] loss:  1.733e-01, time/iteration:  1.329e+01 ms
# [02:49:57] - [step:      28700] loss:  1.271e-01, time/iteration:  1.316e+01 ms
# [02:49:59] - [step:      28800] loss:  2.002e-01, time/iteration:  1.306e+01 ms
# [02:50:00] - [step:      28900] loss:  2.143e-01, time/iteration:  1.300e+01 ms
# [02:50:04] - [step:      29000] record validators time:  2.689e+00s
# [02:50:04] - [step:      29000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:50:04] - [step:      29000] loss:  2.331e-01, time/iteration:  4.286e+01 ms
# [02:50:05] - [step:      29100] loss:  1.985e-01, time/iteration:  1.293e+01 ms
# [02:50:07] - [step:      29200] loss:  1.865e-01, time/iteration:  1.341e+01 ms
# [02:50:08] - [step:      29300] loss:  1.887e-01, time/iteration:  1.317e+01 ms
# [02:50:09] - [step:      29400] loss:  1.362e-01, time/iteration:  1.288e+01 ms
# [02:50:11] - [step:      29500] loss:  2.169e-01, time/iteration:  1.424e+01 ms
# [02:50:12] - [step:      29600] loss:  1.966e-01, time/iteration:  1.321e+01 ms
# [02:50:13] - [step:      29700] loss:  2.220e-01, time/iteration:  1.304e+01 ms
# [02:50:15] - [step:      29800] loss:  1.360e-01, time/iteration:  1.381e+01 ms
# [02:50:16] - [step:      29900] loss:  1.600e-01, time/iteration:  1.314e+01 ms
# [02:50:18] - [step:      30000] record constraint batch time:  3.324e-02s
# [02:50:20] - [step:      30000] record validators time:  2.664e+00s
# [02:50:20] - [step:      30000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:50:20] - [step:      30000] loss:  1.476e-01, time/iteration:  4.319e+01 ms
# [02:50:22] - [step:      30100] loss:  1.493e-01, time/iteration:  1.327e+01 ms
# [02:50:23] - [step:      30200] loss:  1.886e-01, time/iteration:  1.318e+01 ms
# [02:50:24] - [step:      30300] loss:  1.749e-01, time/iteration:  1.313e+01 ms
# [02:50:26] - [step:      30400] loss:  1.220e-01, time/iteration:  1.327e+01 ms
# [02:50:27] - [step:      30500] loss:  1.794e-01, time/iteration:  1.436e+01 ms
# [02:50:28] - [step:      30600] loss:  1.422e-01, time/iteration:  1.307e+01 ms
# [02:50:30] - [step:      30700] loss:  1.375e-01, time/iteration:  1.299e+01 ms
# [02:50:31] - [step:      30800] loss:  1.531e-01, time/iteration:  1.307e+01 ms
# [02:50:32] - [step:      30900] loss:  1.578e-01, time/iteration:  1.288e+01 ms
# [02:50:37] - [step:      31000] record validators time:  2.622e+00s
# [02:50:37] - [step:      31000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:50:37] - [step:      31000] loss:  1.295e-01, time/iteration:  4.214e+01 ms
# [02:50:38] - [step:      31100] loss:  2.021e-01, time/iteration:  1.303e+01 ms
# [02:50:39] - [step:      31200] loss:  1.574e-01, time/iteration:  1.291e+01 ms
# [02:50:40] - [step:      31300] loss:  1.800e-01, time/iteration:  1.276e+01 ms
# [02:50:42] - [step:      31400] loss:  1.312e-01, time/iteration:  1.301e+01 ms
# [02:50:43] - [step:      31500] loss:  2.042e-01, time/iteration:  1.406e+01 ms
# [02:50:44] - [step:      31600] loss:  2.318e-01, time/iteration:  1.302e+01 ms
# [02:50:46] - [step:      31700] loss:  1.274e-01, time/iteration:  1.355e+01 ms
# [02:50:47] - [step:      31800] loss:  1.716e-01, time/iteration:  1.340e+01 ms
# [02:50:48] - [step:      31900] loss:  1.226e-01, time/iteration:  1.301e+01 ms
# [02:50:50] - [step:      32000] record constraint batch time:  3.298e-02s
# [02:50:53] - [step:      32000] record validators time:  2.807e+00s
# [02:50:53] - [step:      32000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:50:53] - [step:      32000] loss:  1.456e-01, time/iteration:  4.445e+01 ms
# [02:50:54] - [step:      32100] loss:  1.661e-01, time/iteration:  1.328e+01 ms
# [02:50:56] - [step:      32200] loss:  1.051e-01, time/iteration:  1.362e+01 ms
# [02:50:57] - [step:      32300] loss:  1.668e-01, time/iteration:  1.366e+01 ms
# [02:50:58] - [step:      32400] loss:  1.420e-01, time/iteration:  1.349e+01 ms
# [02:51:00] - [step:      32500] loss:  1.104e-01, time/iteration:  1.423e+01 ms
# [02:51:01] - [step:      32600] loss:  1.335e-01, time/iteration:  1.353e+01 ms
# [02:51:02] - [step:      32700] loss:  1.600e-01, time/iteration:  1.334e+01 ms
# [02:51:04] - [step:      32800] loss:  1.574e-01, time/iteration:  1.369e+01 ms
# [02:51:05] - [step:      32900] loss:  1.836e-01, time/iteration:  1.337e+01 ms
# [02:51:09] - [step:      33000] record validators time:  2.619e+00s
# [02:51:09] - [step:      33000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:51:09] - [step:      33000] loss:  9.688e-02, time/iteration:  4.244e+01 ms
# [02:51:11] - [step:      33100] loss:  1.800e-01, time/iteration:  1.341e+01 ms
# [02:51:12] - [step:      33200] loss:  8.623e-02, time/iteration:  1.344e+01 ms
# [02:51:13] - [step:      33300] loss:  1.458e-01, time/iteration:  1.330e+01 ms
# [02:51:15] - [step:      33400] loss:  1.492e-01, time/iteration:  1.326e+01 ms
# [02:51:16] - [step:      33500] loss:  1.663e-01, time/iteration:  1.443e+01 ms
# [02:51:17] - [step:      33600] loss:  1.248e-01, time/iteration:  1.342e+01 ms
# [02:51:19] - [step:      33700] loss:  1.495e-01, time/iteration:  1.308e+01 ms
# [02:51:20] - [step:      33800] loss:  9.335e-02, time/iteration:  1.307e+01 ms
# [02:51:21] - [step:      33900] loss:  1.428e-01, time/iteration:  1.314e+01 ms
# [02:51:23] - [step:      34000] record constraint batch time:  3.383e-02s
# [02:51:26] - [step:      34000] record validators time:  2.723e+00s
# [02:51:26] - [step:      34000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:51:26] - [step:      34000] loss:  1.447e-01, time/iteration:  4.370e+01 ms
# [02:51:27] - [step:      34100] loss:  1.309e-01, time/iteration:  1.325e+01 ms
# [02:51:28] - [step:      34200] loss:  1.362e-01, time/iteration:  1.304e+01 ms
# [02:51:30] - [step:      34300] loss:  1.238e-01, time/iteration:  1.298e+01 ms
# [02:51:31] - [step:      34400] loss:  1.486e-01, time/iteration:  1.320e+01 ms
# [02:51:32] - [step:      34500] loss:  9.322e-02, time/iteration:  1.432e+01 ms
# [02:51:34] - [step:      34600] loss:  9.860e-02, time/iteration:  1.342e+01 ms
# [02:51:35] - [step:      34700] loss:  8.419e-02, time/iteration:  1.370e+01 ms
# [02:51:37] - [step:      34800] loss:  9.134e-02, time/iteration:  1.367e+01 ms
# [02:51:38] - [step:      34900] loss:  1.329e-01, time/iteration:  1.306e+01 ms
# [02:51:42] - [step:      35000] record validators time:  2.851e+00s
# [02:51:42] - [step:      35000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:51:42] - [step:      35000] loss:  1.057e-01, time/iteration:  4.445e+01 ms
# [02:51:44] - [step:      35100] loss:  1.203e-01, time/iteration:  1.291e+01 ms
# [02:51:45] - [step:      35200] loss:  1.368e-01, time/iteration:  1.305e+01 ms
# [02:51:46] - [step:      35300] loss:  1.059e-01, time/iteration:  1.317e+01 ms
# [02:51:48] - [step:      35400] loss:  1.214e-01, time/iteration:  1.345e+01 ms
# [02:51:49] - [step:      35500] loss:  1.115e-01, time/iteration:  1.419e+01 ms
# [02:51:50] - [step:      35600] loss:  1.375e-01, time/iteration:  1.328e+01 ms
# [02:51:52] - [step:      35700] loss:  1.328e-01, time/iteration:  1.306e+01 ms
# [02:51:53] - [step:      35800] loss:  1.107e-01, time/iteration:  1.303e+01 ms
# [02:51:54] - [step:      35900] loss:  9.140e-02, time/iteration:  1.293e+01 ms
# [02:51:56] - [step:      36000] record constraint batch time:  3.303e-02s
# [02:51:59] - [step:      36000] record validators time:  2.688e+00s
# [02:51:59] - [step:      36000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:51:59] - [step:      36000] loss:  1.155e-01, time/iteration:  4.337e+01 ms
# [02:52:00] - [step:      36100] loss:  1.066e-01, time/iteration:  1.295e+01 ms
# [02:52:01] - [step:      36200] loss:  8.083e-02, time/iteration:  1.301e+01 ms
# [02:52:02] - [step:      36300] loss:  1.093e-01, time/iteration:  1.309e+01 ms
# [02:52:04] - [step:      36400] loss:  1.356e-01, time/iteration:  1.322e+01 ms
# [02:52:05] - [step:      36500] loss:  1.086e-01, time/iteration:  1.445e+01 ms
# [02:52:07] - [step:      36600] loss:  1.072e-01, time/iteration:  1.363e+01 ms
# [02:52:08] - [step:      36700] loss:  9.590e-02, time/iteration:  1.334e+01 ms
# [02:52:09] - [step:      36800] loss:  1.011e-01, time/iteration:  1.354e+01 ms
# [02:52:11] - [step:      36900] loss:  1.260e-01, time/iteration:  1.320e+01 ms
# [02:52:15] - [step:      37000] record validators time:  2.685e+00s
# [02:52:15] - [step:      37000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:52:15] - [step:      37000] loss:  1.480e-01, time/iteration:  4.316e+01 ms
# [02:52:16] - [step:      37100] loss:  8.210e-02, time/iteration:  1.326e+01 ms
# [02:52:18] - [step:      37200] loss:  8.894e-02, time/iteration:  1.326e+01 ms
# [02:52:19] - [step:      37300] loss:  8.875e-02, time/iteration:  1.301e+01 ms
# [02:52:20] - [step:      37400] loss:  7.601e-02, time/iteration:  1.313e+01 ms
# [02:52:22] - [step:      37500] loss:  9.653e-02, time/iteration:  1.414e+01 ms
# [02:52:23] - [step:      37600] loss:  7.465e-02, time/iteration:  1.326e+01 ms
# [02:52:24] - [step:      37700] loss:  8.561e-02, time/iteration:  1.303e+01 ms
# [02:52:26] - [step:      37800] loss:  7.691e-02, time/iteration:  1.337e+01 ms
# [02:52:27] - [step:      37900] loss:  7.833e-02, time/iteration:  1.344e+01 ms
# [02:52:29] - [step:      38000] record constraint batch time:  3.342e-02s
# [02:52:31] - [step:      38000] record validators time:  2.660e+00s
# [02:52:31] - [step:      38000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:52:31] - [step:      38000] loss:  7.803e-02, time/iteration:  4.296e+01 ms
# [02:52:32] - [step:      38100] loss:  7.593e-02, time/iteration:  1.304e+01 ms
# [02:52:34] - [step:      38200] loss:  9.486e-02, time/iteration:  1.295e+01 ms
# [02:52:35] - [step:      38300] loss:  1.058e-01, time/iteration:  1.323e+01 ms
# [02:52:36] - [step:      38400] loss:  1.149e-01, time/iteration:  1.345e+01 ms
# [02:52:38] - [step:      38500] loss:  9.388e-02, time/iteration:  1.446e+01 ms
# [02:52:39] - [step:      38600] loss:  8.643e-02, time/iteration:  1.326e+01 ms
# [02:52:41] - [step:      38700] loss:  9.570e-02, time/iteration:  1.317e+01 ms
# [02:52:42] - [step:      38800] loss:  7.310e-02, time/iteration:  1.318e+01 ms
# [02:52:43] - [step:      38900] loss:  8.099e-02, time/iteration:  1.337e+01 ms
# [02:52:48] - [step:      39000] record validators time:  2.995e+00s
# [02:52:48] - [step:      39000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:52:48] - [step:      39000] loss:  1.001e-01, time/iteration:  4.630e+01 ms
# [02:52:49] - [step:      39100] loss:  8.978e-02, time/iteration:  1.325e+01 ms
# [02:52:50] - [step:      39200] loss:  8.520e-02, time/iteration:  1.317e+01 ms
# [02:52:52] - [step:      39300] loss:  9.234e-02, time/iteration:  1.313e+01 ms
# [02:52:53] - [step:      39400] loss:  1.031e-01, time/iteration:  1.317e+01 ms
# [02:52:55] - [step:      39500] loss:  8.206e-02, time/iteration:  1.432e+01 ms
# [02:52:56] - [step:      39600] loss:  9.212e-02, time/iteration:  1.347e+01 ms
# [02:52:57] - [step:      39700] loss:  5.787e-02, time/iteration:  1.333e+01 ms
# [02:52:59] - [step:      39800] loss:  1.002e-01, time/iteration:  1.292e+01 ms
# [02:53:00] - [step:      39900] loss:  7.715e-02, time/iteration:  1.305e+01 ms
# [02:53:01] - [step:      40000] record constraint batch time:  3.438e-02s
# [02:53:04] - [step:      40000] record validators time:  2.728e+00s
# [02:53:04] - [step:      40000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:53:04] - [step:      40000] loss:  6.078e-02, time/iteration:  4.416e+01 ms
# [02:53:06] - [step:      40100] loss:  8.377e-02, time/iteration:  1.336e+01 ms
# [02:53:07] - [step:      40200] loss:  8.983e-02, time/iteration:  1.339e+01 ms
# [02:53:08] - [step:      40300] loss:  1.592e-01, time/iteration:  1.313e+01 ms
# [02:53:10] - [step:      40400] loss:  9.001e-02, time/iteration:  1.293e+01 ms
# [02:53:11] - [step:      40500] loss:  9.369e-02, time/iteration:  1.402e+01 ms
# [02:53:12] - [step:      40600] loss:  6.275e-02, time/iteration:  1.311e+01 ms
# [02:53:14] - [step:      40700] loss:  1.084e-01, time/iteration:  1.287e+01 ms
# [02:53:15] - [step:      40800] loss:  9.977e-02, time/iteration:  1.309e+01 ms
# [02:53:16] - [step:      40900] loss:  1.307e-01, time/iteration:  1.306e+01 ms
# [02:53:20] - [step:      41000] record validators time:  2.559e+00s
# [02:53:20] - [step:      41000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:53:20] - [step:      41000] loss:  7.062e-02, time/iteration:  4.162e+01 ms
# [02:53:22] - [step:      41100] loss:  9.500e-02, time/iteration:  1.298e+01 ms
# [02:53:23] - [step:      41200] loss:  7.260e-02, time/iteration:  1.286e+01 ms
# [02:53:24] - [step:      41300] loss:  8.207e-02, time/iteration:  1.308e+01 ms
# [02:53:26] - [step:      41400] loss:  6.817e-02, time/iteration:  1.334e+01 ms
# [02:53:27] - [step:      41500] loss:  6.691e-02, time/iteration:  1.462e+01 ms
# [02:53:28] - [step:      41600] loss:  8.887e-02, time/iteration:  1.313e+01 ms
# [02:53:30] - [step:      41700] loss:  9.711e-02, time/iteration:  1.320e+01 ms
# [02:53:31] - [step:      41800] loss:  6.443e-02, time/iteration:  1.321e+01 ms
# [02:53:32] - [step:      41900] loss:  8.407e-02, time/iteration:  1.314e+01 ms
# [02:53:34] - [step:      42000] record constraint batch time:  3.330e-02s
# [02:53:37] - [step:      42000] record validators time:  2.907e+00s
# [02:53:37] - [step:      42000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:53:37] - [step:      42000] loss:  6.326e-02, time/iteration:  4.556e+01 ms
# [02:53:38] - [step:      42100] loss:  7.924e-02, time/iteration:  1.314e+01 ms
# [02:53:39] - [step:      42200] loss:  8.004e-02, time/iteration:  1.293e+01 ms
# [02:53:41] - [step:      42300] loss:  7.539e-02, time/iteration:  1.328e+01 ms
# [02:53:42] - [step:      42400] loss:  8.549e-02, time/iteration:  1.319e+01 ms
# [02:53:43] - [step:      42500] loss:  8.405e-02, time/iteration:  1.418e+01 ms
# [02:53:45] - [step:      42600] loss:  6.300e-02, time/iteration:  1.352e+01 ms
# [02:53:46] - [step:      42700] loss:  9.910e-02, time/iteration:  1.304e+01 ms
# [02:53:48] - [step:      42800] loss:  9.071e-02, time/iteration:  1.385e+01 ms
# [02:53:49] - [step:      42900] loss:  6.655e-02, time/iteration:  1.290e+01 ms
# [02:53:53] - [step:      43000] record validators time:  2.629e+00s
# [02:53:53] - [step:      43000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:53:53] - [step:      43000] loss:  5.572e-02, time/iteration:  4.236e+01 ms
# [02:53:54] - [step:      43100] loss:  9.672e-02, time/iteration:  1.285e+01 ms
# [02:53:56] - [step:      43200] loss:  7.485e-02, time/iteration:  1.307e+01 ms
# [02:53:57] - [step:      43300] loss:  6.302e-02, time/iteration:  1.339e+01 ms
# [02:53:58] - [step:      43400] loss:  5.814e-02, time/iteration:  1.283e+01 ms
# [02:54:00] - [step:      43500] loss:  9.882e-02, time/iteration:  1.397e+01 ms
# [02:54:01] - [step:      43600] loss:  7.246e-02, time/iteration:  1.335e+01 ms
# [02:54:02] - [step:      43700] loss:  9.334e-02, time/iteration:  1.329e+01 ms
# [02:54:04] - [step:      43800] loss:  7.367e-02, time/iteration:  1.324e+01 ms
# [02:54:05] - [step:      43900] loss:  8.538e-02, time/iteration:  1.353e+01 ms
# [02:54:07] - [step:      44000] record constraint batch time:  3.315e-02s
# [02:54:09] - [step:      44000] record validators time:  2.691e+00s
# [02:54:09] - [step:      44000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:54:09] - [step:      44000] loss:  7.296e-02, time/iteration:  4.364e+01 ms
# [02:54:11] - [step:      44100] loss:  9.270e-02, time/iteration:  1.309e+01 ms
# [02:54:12] - [step:      44200] loss:  6.936e-02, time/iteration:  1.311e+01 ms
# [02:54:13] - [step:      44300] loss:  5.559e-02, time/iteration:  1.304e+01 ms
# [02:54:15] - [step:      44400] loss:  7.357e-02, time/iteration:  1.316e+01 ms
# [02:54:16] - [step:      44500] loss:  7.398e-02, time/iteration:  1.413e+01 ms
# [02:54:17] - [step:      44600] loss:  7.435e-02, time/iteration:  1.355e+01 ms
# [02:54:19] - [step:      44700] loss:  6.450e-02, time/iteration:  1.292e+01 ms
# [02:54:20] - [step:      44800] loss:  6.793e-02, time/iteration:  1.322e+01 ms
# [02:54:21] - [step:      44900] loss:  7.732e-02, time/iteration:  1.319e+01 ms
# [02:54:25] - [step:      45000] record validators time:  2.585e+00s
# [02:54:25] - [step:      45000] saved checkpoint to outputs/fhn1P/initial_conditions
# [02:54:25] - [step:      45000] loss:  8.104e-02, time/iteration:  4.167e+01 ms
# ...
# [03:04:59] - [step:      84100] loss:  2.179e-02, time/iteration:  1.299e+01 ms
# [03:05:00] - [step:      84200] loss:  2.049e-02, time/iteration:  1.309e+01 ms
# [03:05:01] - [step:      84300] loss:  2.312e-02, time/iteration:  1.307e+01 ms
# [03:05:03] - [step:      84400] loss:  2.026e-02, time/iteration:  1.316e+01 ms
# [03:05:04] - [step:      84500] loss:  2.054e-02, time/iteration:  1.459e+01 ms
# [03:05:05] - [step:      84600] loss:  1.903e-02, time/iteration:  1.338e+01 ms
# [03:05:07] - [step:      84700] loss:  1.596e-02, time/iteration:  1.324e+01 ms
# [03:05:08] - [step:      84800] loss:  2.213e-02, time/iteration:  1.308e+01 ms
# [03:05:09] - [step:      84900] loss:  2.142e-02, time/iteration:  1.308e+01 ms
# [03:05:14] - [step:      85000] record validators time:  2.674e+00s
# [03:05:14] - [step:      85000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:05:14] - [step:      85000] loss:  1.703e-02, time/iteration:  4.301e+01 ms
# [03:05:15] - [step:      85100] loss:  1.912e-02, time/iteration:  1.328e+01 ms
# [03:05:16] - [step:      85200] loss:  1.561e-02, time/iteration:  1.345e+01 ms
# [03:05:18] - [step:      85300] loss:  1.994e-02, time/iteration:  1.316e+01 ms
# [03:05:19] - [step:      85400] loss:  2.209e-02, time/iteration:  1.298e+01 ms
# [03:05:20] - [step:      85500] loss:  2.192e-02, time/iteration:  1.409e+01 ms
# [03:05:22] - [step:      85600] loss:  1.624e-02, time/iteration:  1.306e+01 ms
# [03:05:23] - [step:      85700] loss:  1.790e-02, time/iteration:  1.313e+01 ms
# [03:05:24] - [step:      85800] loss:  2.010e-02, time/iteration:  1.313e+01 ms
# [03:05:26] - [step:      85900] loss:  2.124e-02, time/iteration:  1.320e+01 ms
# [03:05:27] - [step:      86000] record constraint batch time:  3.250e-02s
# [03:05:30] - [step:      86000] record validators time:  2.577e+00s
# [03:05:30] - [step:      86000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:05:30] - [step:      86000] loss:  2.234e-02, time/iteration:  4.242e+01 ms
# [03:05:31] - [step:      86100] loss:  1.756e-02, time/iteration:  1.279e+01 ms
# [03:05:32] - [step:      86200] loss:  2.168e-02, time/iteration:  1.277e+01 ms
# [03:05:34] - [step:      86300] loss:  2.744e-02, time/iteration:  1.320e+01 ms
# [03:05:35] - [step:      86400] loss:  2.072e-02, time/iteration:  1.310e+01 ms
# [03:05:36] - [step:      86500] loss:  2.363e-02, time/iteration:  1.405e+01 ms
# [03:05:38] - [step:      86600] loss:  2.159e-02, time/iteration:  1.295e+01 ms
# [03:05:39] - [step:      86700] loss:  2.102e-02, time/iteration:  1.280e+01 ms
# [03:05:40] - [step:      86800] loss:  2.212e-02, time/iteration:  1.300e+01 ms
# [03:05:42] - [step:      86900] loss:  2.370e-02, time/iteration:  1.328e+01 ms
# [03:05:46] - [step:      87000] record validators time:  2.512e+00s
# [03:05:46] - [step:      87000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:05:46] - [step:      87000] loss:  2.181e-02, time/iteration:  4.101e+01 ms
# [03:05:47] - [step:      87100] loss:  2.164e-02, time/iteration:  1.344e+01 ms
# [03:05:48] - [step:      87200] loss:  2.780e-02, time/iteration:  1.299e+01 ms
# [03:05:50] - [step:      87300] loss:  1.993e-02, time/iteration:  1.299e+01 ms
# [03:05:51] - [step:      87400] loss:  2.153e-02, time/iteration:  1.312e+01 ms
# [03:05:52] - [step:      87500] loss:  2.168e-02, time/iteration:  1.408e+01 ms
# [03:05:54] - [step:      87600] loss:  3.263e-02, time/iteration:  1.305e+01 ms
# [03:05:55] - [step:      87700] loss:  1.916e-02, time/iteration:  1.325e+01 ms
# [03:05:56] - [step:      87800] loss:  2.022e-02, time/iteration:  1.332e+01 ms
# [03:05:58] - [step:      87900] loss:  1.831e-02, time/iteration:  1.295e+01 ms
# [03:05:59] - [step:      88000] record constraint batch time:  3.229e-02s
# [03:06:02] - [step:      88000] record validators time:  2.770e+00s
# [03:06:02] - [step:      88000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:06:02] - [step:      88000] loss:  2.286e-02, time/iteration:  4.416e+01 ms
# [03:06:03] - [step:      88100] loss:  1.967e-02, time/iteration:  1.326e+01 ms
# [03:06:05] - [step:      88200] loss:  2.365e-02, time/iteration:  1.346e+01 ms
# [03:06:06] - [step:      88300] loss:  2.031e-02, time/iteration:  1.298e+01 ms
# [03:06:07] - [step:      88400] loss:  1.678e-02, time/iteration:  1.346e+01 ms
# [03:06:09] - [step:      88500] loss:  1.610e-02, time/iteration:  1.412e+01 ms
# [03:06:10] - [step:      88600] loss:  1.697e-02, time/iteration:  1.318e+01 ms
# [03:06:11] - [step:      88700] loss:  2.049e-02, time/iteration:  1.305e+01 ms
# [03:06:13] - [step:      88800] loss:  2.051e-02, time/iteration:  1.295e+01 ms
# [03:06:14] - [step:      88900] loss:  1.989e-02, time/iteration:  1.285e+01 ms
# [03:06:18] - [step:      89000] record validators time:  2.535e+00s
# [03:06:18] - [step:      89000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:06:18] - [step:      89000] loss:  2.296e-02, time/iteration:  4.127e+01 ms
# [03:06:19] - [step:      89100] loss:  1.813e-02, time/iteration:  1.291e+01 ms
# [03:06:21] - [step:      89200] loss:  1.582e-02, time/iteration:  1.292e+01 ms
# [03:06:22] - [step:      89300] loss:  1.542e-02, time/iteration:  1.299e+01 ms
# [03:06:23] - [step:      89400] loss:  1.888e-02, time/iteration:  1.335e+01 ms
# [03:06:25] - [step:      89500] loss:  1.715e-02, time/iteration:  1.454e+01 ms
# [03:06:26] - [step:      89600] loss:  1.709e-02, time/iteration:  1.317e+01 ms
# [03:06:27] - [step:      89700] loss:  1.876e-02, time/iteration:  1.342e+01 ms
# [03:06:29] - [step:      89800] loss:  1.735e-02, time/iteration:  1.308e+01 ms
# [03:06:30] - [step:      89900] loss:  1.539e-02, time/iteration:  1.317e+01 ms
# [03:06:32] - [step:      90000] record constraint batch time:  3.309e-02s
# [03:06:34] - [step:      90000] record validators time:  2.711e+00s
# [03:06:34] - [step:      90000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:06:34] - [step:      90000] loss:  1.837e-02, time/iteration:  4.338e+01 ms
# [03:06:36] - [step:      90100] loss:  1.725e-02, time/iteration:  1.325e+01 ms
# [03:06:37] - [step:      90200] loss:  1.660e-02, time/iteration:  1.328e+01 ms
# [03:06:38] - [step:      90300] loss:  1.845e-02, time/iteration:  1.303e+01 ms
# [03:06:40] - [step:      90400] loss:  1.687e-02, time/iteration:  1.345e+01 ms
# [03:06:41] - [step:      90500] loss:  1.821e-02, time/iteration:  1.433e+01 ms
# [03:06:43] - [step:      90600] loss:  2.121e-02, time/iteration:  1.310e+01 ms
# [03:06:44] - [step:      90700] loss:  2.157e-02, time/iteration:  1.316e+01 ms
# [03:06:45] - [step:      90800] loss:  1.776e-02, time/iteration:  1.321e+01 ms
# [03:06:46] - [step:      90900] loss:  1.550e-02, time/iteration:  1.333e+01 ms
# [03:06:51] - [step:      91000] record validators time:  2.831e+00s
# [03:06:51] - [step:      91000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:06:51] - [step:      91000] loss:  1.770e-02, time/iteration:  4.415e+01 ms
# [03:06:52] - [step:      91100] loss:  1.730e-02, time/iteration:  1.302e+01 ms
# [03:06:54] - [step:      91200] loss:  1.558e-02, time/iteration:  1.308e+01 ms
# [03:06:55] - [step:      91300] loss:  1.619e-02, time/iteration:  1.325e+01 ms
# [03:06:56] - [step:      91400] loss:  2.306e-02, time/iteration:  1.304e+01 ms
# [03:06:58] - [step:      91500] loss:  1.758e-02, time/iteration:  1.438e+01 ms
# [03:06:59] - [step:      91600] loss:  1.916e-02, time/iteration:  1.305e+01 ms
# [03:07:00] - [step:      91700] loss:  2.130e-02, time/iteration:  1.310e+01 ms
# [03:07:02] - [step:      91800] loss:  1.554e-02, time/iteration:  1.315e+01 ms
# [03:07:03] - [step:      91900] loss:  1.805e-02, time/iteration:  1.308e+01 ms
# [03:07:04] - [step:      92000] record constraint batch time:  3.312e-02s
# [03:07:07] - [step:      92000] record validators time:  2.674e+00s
# [03:07:07] - [step:      92000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:07:07] - [step:      92000] loss:  1.524e-02, time/iteration:  4.301e+01 ms
# [03:07:08] - [step:      92100] loss:  2.148e-02, time/iteration:  1.300e+01 ms
# [03:07:10] - [step:      92200] loss:  1.995e-02, time/iteration:  1.325e+01 ms
# [03:07:11] - [step:      92300] loss:  1.646e-02, time/iteration:  1.314e+01 ms
# [03:07:12] - [step:      92400] loss:  1.762e-02, time/iteration:  1.307e+01 ms
# [03:07:14] - [step:      92500] loss:  1.662e-02, time/iteration:  1.449e+01 ms
# [03:07:15] - [step:      92600] loss:  1.521e-02, time/iteration:  1.326e+01 ms
# [03:07:16] - [step:      92700] loss:  1.980e-02, time/iteration:  1.327e+01 ms
# [03:07:18] - [step:      92800] loss:  1.505e-02, time/iteration:  1.298e+01 ms
# [03:07:19] - [step:      92900] loss:  1.698e-02, time/iteration:  1.298e+01 ms
# [03:07:23] - [step:      93000] record validators time:  2.530e+00s
# [03:07:23] - [step:      93000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:07:23] - [step:      93000] loss:  1.603e-02, time/iteration:  4.124e+01 ms
# [03:07:24] - [step:      93100] loss:  2.062e-02, time/iteration:  1.286e+01 ms
# [03:07:26] - [step:      93200] loss:  1.626e-02, time/iteration:  1.337e+01 ms
# [03:07:27] - [step:      93300] loss:  1.760e-02, time/iteration:  1.336e+01 ms
# [03:07:28] - [step:      93400] loss:  1.740e-02, time/iteration:  1.307e+01 ms
# [03:07:30] - [step:      93500] loss:  2.065e-02, time/iteration:  1.416e+01 ms
# [03:07:31] - [step:      93600] loss:  1.926e-02, time/iteration:  1.303e+01 ms
# [03:07:32] - [step:      93700] loss:  1.924e-02, time/iteration:  1.316e+01 ms
# [03:07:34] - [step:      93800] loss:  1.950e-02, time/iteration:  1.301e+01 ms
# [03:07:35] - [step:      93900] loss:  1.551e-02, time/iteration:  1.325e+01 ms
# [03:07:37] - [step:      94000] record constraint batch time:  3.201e-02s
# [03:07:39] - [step:      94000] record validators time:  2.478e+00s
# [03:07:39] - [step:      94000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:07:39] - [step:      94000] loss:  1.918e-02, time/iteration:  4.090e+01 ms
# [03:07:41] - [step:      94100] loss:  2.024e-02, time/iteration:  1.302e+01 ms
# [03:07:42] - [step:      94200] loss:  1.552e-02, time/iteration:  1.294e+01 ms
# [03:07:43] - [step:      94300] loss:  2.129e-02, time/iteration:  1.285e+01 ms
# [03:07:44] - [step:      94400] loss:  1.750e-02, time/iteration:  1.289e+01 ms
# [03:07:46] - [step:      94500] loss:  1.706e-02, time/iteration:  1.421e+01 ms
# [03:07:47] - [step:      94600] loss:  1.743e-02, time/iteration:  1.344e+01 ms
# [03:07:48] - [step:      94700] loss:  1.599e-02, time/iteration:  1.295e+01 ms
# [03:07:50] - [step:      94800] loss:  1.622e-02, time/iteration:  1.302e+01 ms
# [03:07:51] - [step:      94900] loss:  1.325e-02, time/iteration:  1.318e+01 ms
# [03:07:55] - [step:      95000] record validators time:  2.840e+00s
# [03:07:55] - [step:      95000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:07:55] - [step:      95000] loss:  1.470e-02, time/iteration:  4.437e+01 ms
# [03:07:57] - [step:      95100] loss:  2.071e-02, time/iteration:  1.373e+01 ms
# [03:07:58] - [step:      95200] loss:  2.052e-02, time/iteration:  1.316e+01 ms
# [03:07:59] - [step:      95300] loss:  1.571e-02, time/iteration:  1.294e+01 ms
# [03:08:01] - [step:      95400] loss:  1.570e-02, time/iteration:  1.320e+01 ms
# [03:08:02] - [step:      95500] loss:  1.478e-02, time/iteration:  1.456e+01 ms
# [03:08:04] - [step:      95600] loss:  1.535e-02, time/iteration:  1.330e+01 ms
# [03:08:05] - [step:      95700] loss:  1.864e-02, time/iteration:  1.319e+01 ms
# [03:08:06] - [step:      95800] loss:  1.525e-02, time/iteration:  1.307e+01 ms
# [03:08:08] - [step:      95900] loss:  1.590e-02, time/iteration:  1.345e+01 ms
# [03:08:09] - [step:      96000] record constraint batch time:  3.250e-02s
# [03:08:12] - [step:      96000] record validators time:  2.594e+00s
# [03:08:12] - [step:      96000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:08:12] - [step:      96000] loss:  1.390e-02, time/iteration:  4.189e+01 ms
# [03:08:13] - [step:      96100] loss:  1.806e-02, time/iteration:  1.296e+01 ms
# [03:08:14] - [step:      96200] loss:  2.018e-02, time/iteration:  1.298e+01 ms
# [03:08:16] - [step:      96300] loss:  1.435e-02, time/iteration:  1.300e+01 ms
# [03:08:17] - [step:      96400] loss:  1.927e-02, time/iteration:  1.333e+01 ms
# [03:08:18] - [step:      96500] loss:  1.545e-02, time/iteration:  1.397e+01 ms
# [03:08:20] - [step:      96600] loss:  1.483e-02, time/iteration:  1.292e+01 ms
# [03:08:21] - [step:      96700] loss:  1.445e-02, time/iteration:  1.290e+01 ms
# [03:08:22] - [step:      96800] loss:  1.409e-02, time/iteration:  1.282e+01 ms
# [03:08:24] - [step:      96900] loss:  1.394e-02, time/iteration:  1.296e+01 ms
# [03:08:28] - [step:      97000] record validators time:  2.578e+00s
# [03:08:28] - [step:      97000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:08:28] - [step:      97000] loss:  1.432e-02, time/iteration:  4.156e+01 ms
# [03:08:29] - [step:      97100] loss:  1.494e-02, time/iteration:  1.289e+01 ms
# [03:08:30] - [step:      97200] loss:  1.249e-02, time/iteration:  1.317e+01 ms
# [03:08:32] - [step:      97300] loss:  1.632e-02, time/iteration:  1.274e+01 ms
# [03:08:33] - [step:      97400] loss:  1.583e-02, time/iteration:  1.297e+01 ms
# [03:08:34] - [step:      97500] loss:  1.401e-02, time/iteration:  1.408e+01 ms
# [03:08:36] - [step:      97600] loss:  1.343e-02, time/iteration:  1.360e+01 ms
# [03:08:37] - [step:      97700] loss:  1.904e-02, time/iteration:  1.319e+01 ms
# [03:08:38] - [step:      97800] loss:  1.454e-02, time/iteration:  1.313e+01 ms
# [03:08:40] - [step:      97900] loss:  1.506e-02, time/iteration:  1.293e+01 ms
# [03:08:41] - [step:      98000] record constraint batch time:  3.615e-02s
# [03:08:44] - [step:      98000] record validators time:  2.857e+00s
# [03:08:44] - [step:      98000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:08:44] - [step:      98000] loss:  1.249e-02, time/iteration:  4.503e+01 ms
# [03:08:45] - [step:      98100] loss:  1.703e-02, time/iteration:  1.330e+01 ms
# [03:08:47] - [step:      98200] loss:  1.354e-02, time/iteration:  1.329e+01 ms
# [03:08:48] - [step:      98300] loss:  1.861e-02, time/iteration:  1.308e+01 ms
# [03:08:49] - [step:      98400] loss:  1.362e-02, time/iteration:  1.358e+01 ms
# [03:08:51] - [step:      98500] loss:  1.436e-02, time/iteration:  1.449e+01 ms
# [03:08:52] - [step:      98600] loss:  1.543e-02, time/iteration:  1.309e+01 ms
# [03:08:53] - [step:      98700] loss:  1.636e-02, time/iteration:  1.302e+01 ms
# [03:08:55] - [step:      98800] loss:  1.761e-02, time/iteration:  1.309e+01 ms
# [03:08:56] - [step:      98900] loss:  1.305e-02, time/iteration:  1.306e+01 ms
# [03:09:00] - [step:      99000] record validators time:  2.589e+00s
# [03:09:00] - [step:      99000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:09:00] - [step:      99000] loss:  1.508e-02, time/iteration:  4.183e+01 ms
# [03:09:02] - [step:      99100] loss:  1.643e-02, time/iteration:  1.291e+01 ms
# [03:09:03] - [step:      99200] loss:  1.454e-02, time/iteration:  1.347e+01 ms
# [03:09:04] - [step:      99300] loss:  1.583e-02, time/iteration:  1.293e+01 ms
# [03:09:06] - [step:      99400] loss:  1.809e-02, time/iteration:  1.323e+01 ms
# [03:09:07] - [step:      99500] loss:  1.317e-02, time/iteration:  1.417e+01 ms
# [03:09:08] - [step:      99600] loss:  1.263e-02, time/iteration:  1.298e+01 ms
# [03:09:09] - [step:      99700] loss:  1.976e-02, time/iteration:  1.277e+01 ms
# [03:09:11] - [step:      99800] loss:  1.747e-02, time/iteration:  1.304e+01 ms
# [03:09:12] - [step:      99900] loss:  1.523e-02, time/iteration:  1.287e+01 ms
# [03:09:14] - [step:     100000] record constraint batch time:  3.274e-02s
# [03:09:16] - [step:     100000] record validators time:  2.616e+00s
# [03:09:16] - [step:     100000] saved checkpoint to outputs/fhn1P/initial_conditions
# [03:09:16] - [step:     100000] loss:  1.824e-02, time/iteration:  4.226e+01 ms
# [03:09:16] - [step:     100000] reached maximum training steps, finished training!
